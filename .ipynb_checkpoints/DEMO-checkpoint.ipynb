# %% [markdown]
# ## Chamada para apenas 1(um) arquivo
# ### Lendo uma imagem

# %%
import cv2
import json
import requests
import numpy as np
import matplotlib.pyplot as plt

# %%
# BASE_PATH = '/home/italojs/black_images/page2.jpeg'
BASE_PATH = '/home/italojs/black_images/page1.jpeg'

# %%
img = cv2.imread(BASE_PATH)
plt.figure(figsize=(10,20))
plt.imshow(img)
# img = cv2.fastNlMeansDenoisingColored(img,None,4,4,7,21)

grayscaled = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
retval, threshold = cv2.threshold(grayscaled, 15, 255, cv2.THRESH_BINARY)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-9-a3a24d72fe10> in <module>()
#       4 # img = cv2.fastNlMeansDenoisingColored(img,None,4,4,7,21)
#       5
# ----> 6 grayscaled = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#       7 retval, threshold = cv2.threshold(grayscaled, 15, 255, cv2.THRESH_BINARY)
#
# error: OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %% [markdown]
# # Tratando nossa imagem

# %%
threshold.shape
# Out:
# (1280, 1280)

# %% [markdown]
# ### Visualizando nossa imagem

# %%
plt.figure(figsize=(10,20))
plt.imshow(threshold)

# %% [markdown]
# # Visualizando as camadas da nossa imagem

# %%
figure, plots = plt.subplots(ncols=3, nrows=1, figsize=(20,15))

for i, subplot in zip(range(3), plots):
    temp = np.zeros(threshold.shape, dtype='uint8')
    temp[:,:,i] = threshold[:,:,i]
    subplot.imshow(temp)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-112-84c5ba49f821> in <module>
#       3 for i, subplot in zip(range(3), plots):
#       4     temp = np.zeros(threshold.shape, dtype='uint8')
# ----> 5     temp[:,:,i] = threshold[:,:,i]
#       6     subplot.imshow(temp)
#       7 plt.show()
#
# IndexError: too many indices for array

# %%
plt.figure(figsize=(10,20))
plt.imshow(threshold[:, :, 2])

# %% [markdown]
# # Removendo ruidos da nossa imagem

# %% [markdown]
# ### Recortando nossa imagem

# %%
t_y,b_y,l_x  = 210, 650, 190
cropped_image = threshold[t_y:b_y,l_x:]

# %%
plt.figure(figsize=(20,20))
plt.imshow(cropped_image)

# %%
KEY = 'b0eb41fcc20b427c883112c1e6150220'
visionBaseUrl = 'https://brazilsouth.api.cognitive.microsoft.com/vision/v2.0/'
ocrUrl = visionBaseUrl + "ocr"

_, encoded_image = cv2.imencode('.png', grayscaled)
buffer = encoded_image.tobytes()
    
headers = {'Ocp-Apim-Subscription-Key': KEY,
        'Content-Type': 'application/octet-stream'}
params  = {'detectOrientation': 'true'}
# 'language: pt'

try:
    response = requests.post(ocrUrl, headers=headers, params=params, data=buffer)
    response.raise_for_status()

    analysis = response.json()
except Exception as e:
    raise Exception(e)
    
print(json.dumps(analysis, indent=2))
# Out:
# {
#   "language": "unk",
#   "textAngle": 0.0,
#   "orientation": "NotDetected",
#   "regions": []
# }

# %%
line_infos = [region["lines"] for region in analysis["regions"]]
texts = []
for line in line_infos:
    for wordMetadata in line:
        for wordInfo in wordMetadata["words"]:
            texts.append(wordInfo["text"])

image_name = ' '.join(texts)
print(texts)
# Out:
# []
